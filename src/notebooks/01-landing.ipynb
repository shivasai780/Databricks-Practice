# %%
# %run ../common/config

# %%
# %run ../common/utils

# %%
print(ENV)
print(get_config())
print(get_catalog())
print(get_schema())

# %%
import uuid

batch_id = str(uuid.uuid4())

rows_read = 150000

file_name = "orders.csv"

# %%
dbutils.jobs.taskValues.set(
    key="batch_id",
    value=batch_id
)

dbutils.jobs.taskValues.set(
    key="rows_read",
    value=rows_read
)

dbutils.jobs.taskValues.set(
    key="file_name",
    value=file_name
)
