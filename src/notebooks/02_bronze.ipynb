# %%
batch_id = dbutils.jobs.taskValues.get(
    taskKey="Landing",
    key="batch_id",
    default=""
)

rows = dbutils.jobs.taskValues.get(
    taskKey="Landing",
    key="rows_read",
    default=0
)

file = dbutils.jobs.taskValues.get(
    taskKey="Landing",
    key="file_name",
    default=""
)

# %%
print(batch_id)

print(rows)

print(file)
