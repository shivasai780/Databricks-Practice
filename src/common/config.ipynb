# %%
# dbutils.widgets.dropdown(
#     "ENV",
#     "dev",#this is the default value we want
#     ["dev","uat","prod"]
# )
dbutils.widgets.text(
    "ENV",
    "dev"
)

# %%
ENV = dbutils.widgets.get("ENV")

CONFIG = {

    "dev": {

        "catalog": "dev_catalog",
        "schema": "sales",

    },

    "uat": {

        "catalog": "uat_catalog",
        "schema": "sales",

    },

    "prod": {

        "catalog": "prod_catalog",
        "schema": "sales",

    }

}

# %%
current_catalog=CONFIG[ENV]
